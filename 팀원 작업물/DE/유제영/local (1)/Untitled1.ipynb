# %%
import pandas as pd

# %%
df1=pd.DataFrame(data=[[1,2,3], [4,5,6]])
df2= pd.DataFrame(data=[[1,2,3], [4,5,6]])
pd.concat([df1,df2])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 0  1  2  3
# 1  4  5  6

# %%
df=pd.read_csv('final_weather_2004_2011_8.csv', encoding='utf-8')
one_day = df[df['tm']=='2012-01-01 00:00']
# Out:
# C:\Users\yujeyeong\AppData\Local\Temp\ipykernel_28072\3322840456.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('final_weather_2004_2011_8.csv', encoding='utf-8')

# %%
sigun = pd.read_csv('2018년소멸위험지수.csv', encoding='cp949')
sigun['sigun_nm']=sigun['sigun_nm'].map(lambda x:x[:-1])
sigun_small=sigun[['sigun_nm','sigun_code']]

# %%
df=pd.read_csv('predicted.csv', encoding='utf-8')
df[df['label']==1]
one_day = df[df['일시']=='2012-02-05 15:00:00']

# %%
df[df['label']==1 ]
df[df['일시']=='2012-02-05 15:00:00'].iloc[60:90]
# Out:
#          Unnamed: 0                   일시  지점명   기온  강수량   풍속     풍향    습도  \
# 1293192     1298204  2012-02-05 15:00:00   남원  3.7  0.0  0.8  180.0  52.0
# 1314731     1319828  2012-02-05 15:00:00   장수  3.8  0.0  0.5   70.0  60.0
# 1336329     1341452  2012-02-05 15:00:00  고창군  5.0  0.0  1.9  340.0  47.0
# 1357878     1363068  2012-02-05 15:00:00  영광군  5.2  0.0  1.3  110.0  43.0
# 1378620     1384672  2012-02-05 15:00:00  김해시  7.2  0.0  1.7  320.0  37.0
# 1400089     1406267  2012-02-05 15:00:00  순창군  4.6  0.0  1.6  110.0  53.0
# 1421662     1427883  2012-02-05 15:00:00  북창원  5.5  0.0  0.3    0.0  30.0
# 1442161     1449502  2012-02-05 15:00:00  양산시  6.6  0.0  2.4  230.0  30.0
# 1463729     1471126  2012-02-05 15:00:00  보성군  1.0  0.0  1.0  140.0  92.0
# 1485326     1492750  2012-02-05 15:00:00  강진군  1.7  0.1  0.8   50.0  83.0
# 1506886     1514364  2012-02-05 15:00:00   장흥  2.3  0.1  0.1    0.0  83.0
# 1528458     1535988  2012-02-05 15:00:00   해남  4.1  0.1  0.6   50.0  77.0
# 1549884     1557581  2012-02-05 15:00:00   고흥  1.8  0.2  0.5  320.0  86.0
# 1571408     1579190  2012-02-05 15:00:00  의령군  5.3  0.0  1.0  110.0  48.0
# 1592910     1600814  2012-02-05 15:00:00  함양군  4.6  0.0  0.3    0.0  56.0
# 1614174     1622399  2012-02-05 15:00:00  광양시  4.0  0.0  0.1    0.0  62.0
# 1635433     1643958  2012-02-05 15:00:00   봉화  4.9  0.0  1.8  200.0  25.0
# 1656873     1665551  2012-02-05 15:00:00   영주  5.0  0.0  1.7  180.0  29.0
# 1678473     1687175  2012-02-05 15:00:00   문경  5.1  0.0  2.7  160.0  22.0
# 1700025     1708791  2012-02-05 15:00:00  청송군  4.8  0.0  2.7  270.0  18.0
# 1721454     1730415  2012-02-05 15:00:00   영덕  7.9  0.0  2.9  270.0  16.0
# 1742966     1752037  2012-02-05 15:00:00   의성  6.4  0.0  2.4  250.0  11.0
# 1764536     1773661  2012-02-05 15:00:00   구미  5.9  0.0  0.9   90.0  28.0
# 1786139     1795285  2012-02-05 15:00:00   영천  6.5  0.0  1.5  250.0  24.0
# 1807716     1816909  2012-02-05 15:00:00  경주시  6.5  0.0  2.3  320.0  17.0
# 1829251     1838520  2012-02-05 15:00:00   거창  4.3  0.0  0.9   20.0  43.0
# 1850851     1860144  2012-02-05 15:00:00   합천  6.6  0.0  0.6  140.0  35.0
# 1872449     1881768  2012-02-05 15:00:00   밀양  6.6  0.0  1.6  160.0  31.0
# 1894026     1903389  2012-02-05 15:00:00   산청  5.1  0.0  0.6  320.0  46.0
# 1915450     1925001  2012-02-05 15:00:00   거제  3.0  0.0  0.7   20.0  75.0
#
#           실효습도  label day_name  Month  pred     proba
# 1293192  36.95      0   Sunday      2     1  0.616297
# 1314731  45.13      0   Sunday      2     1  0.567289
# 1336329  45.03      0   Sunday      2     0  0.373966
# 1357878  48.08      0   Sunday      2     0  0.297517
# 1378620  23.10      0   Sunday      2     1  0.764818
# 1400089  41.07      0   Sunday      2     1  0.576461
# 1421662  19.28      0   Sunday      2     1  0.751074
# 1442161  20.99      0   Sunday      2     1  0.742103
# 1463729  51.94      0   Sunday      2     1  0.785685
# 1485326  51.06      0   Sunday      2     1  0.705910
# 1506886  49.19      0   Sunday      2     1  0.796825
# 1528458  52.06      0   Sunday      2     1  0.626872
# 1549884  45.95      0   Sunday      2     1  0.629477
# 1571408  30.77      0   Sunday      2     1  0.670507
# 1592910  42.17      0   Sunday      2     1  0.646908
# 1614174  37.44      0   Sunday      2     1  0.802262
# 1635433  21.38      0   Sunday      2     1  0.708902
# 1656873  25.83      0   Sunday      2     1  0.689867
# 1678473  23.14      0   Sunday      2     1  0.708686
# 1700025  25.06      0   Sunday      2     1  0.644491
# 1721454  22.00      0   Sunday      2     1  0.706604
# 1742966  21.80      0   Sunday      2     1  0.710317
# 1764536  30.77      0   Sunday      2     1  0.617923
# 1786139  22.10      0   Sunday      2     1  0.753091
# 1807716  18.33      0   Sunday      2     1  0.712470
# 1829251  31.21      0   Sunday      2     1  0.507742
# 1850851  23.81      0   Sunday      2     1  0.736327
# 1872449  22.20      0   Sunday      2     1  0.756187
# 1894026  30.35      0   Sunday      2     1  0.674200
# 1915450  37.75      0   Sunday      2     1  0.868929

# %%
sigun_small
# Out:
#     sigun_nm  sigun_code
# 0         강릉       42150
# 1         고성       42820
# 2         동해       42170
# 3         삼척       42230
# 4         속초       42210
# ..       ...         ...
# 223       제천       43150
# 224       증평       43745
# 225       진천       43750
# 226       청주       43110
# 227       충주       43130
#
# [228 rows x 2 columns]

# %%
one_day_sample=pd.merge(left = one_day , right = sigun_small, how = "inner", left_on = "지점명", right_on = "sigun_nm")
one_day_sample
# Out:
#     Unnamed: 0                   일시  지점명   기온  강수량   풍속     풍향    습도   실효습도  \
# 0          855  2012-02-05 15:00:00   속초  6.2  0.0  2.2  140.0  32.0  20.68
# 1        22479  2012-02-05 15:00:00   철원  2.5  0.0  1.3  160.0  19.0  21.06
# 2        44103  2012-02-05 15:00:00  동두천  5.1  0.0  1.0  140.0  22.0  21.76
# 3        65726  2012-02-05 15:00:00   파주  2.9  0.0  1.5  290.0  29.0  24.43
# 4       108972  2012-02-05 15:00:00   춘천  2.9  0.0  1.4  110.0  23.0  22.13
# ..         ...                  ...  ...  ...  ...  ...    ...   ...    ...
# 57     1860144  2012-02-05 15:00:00   합천  6.6  0.0  0.6  140.0  35.0  23.81
# 58     1881768  2012-02-05 15:00:00   밀양  6.6  0.0  1.6  160.0  31.0  22.20
# 59     1903389  2012-02-05 15:00:00   산청  5.1  0.0  0.6  320.0  46.0  30.35
# 60     1925001  2012-02-05 15:00:00   거제  3.0  0.0  0.7   20.0  75.0  37.75
# 61     1946619  2012-02-05 15:00:00   남해  1.9  0.0  0.7   90.0  74.0  37.56
#
#     label day_name  Month  pred     proba sigun_nm  sigun_code
# 0       1   Sunday      2     1  0.754163       속초       42210
# 1       0   Sunday      2     1  0.631059       철원       42780
# 2       0   Sunday      2     1  0.721947      동두천       41250
# 3       0   Sunday      2     1  0.689913       파주       41480
# 4       0   Sunday      2     1  0.687121       춘천       42110
# ..    ...      ...    ...   ...       ...      ...         ...
# 57      0   Sunday      2     1  0.736327       합천       48890
# 58      0   Sunday      2     1  0.756187       밀양       48270
# 59      0   Sunday      2     1  0.674200       산청       48860
# 60      0   Sunday      2     1  0.868929       거제       48310
# 61      0   Sunday      2     1  0.829009       남해       48840
#
# [62 rows x 16 columns]

# %%
one_day_sample.to_csv('one_day_predicted.csv')

# %%
df.기온.tolist()
# Out:
# [5.0,
#  4.9,
#  4.1,
#  4.3,
#  3.7,
#  3.2,
#  3.0,
#  3.7,
#  6.3,
#  8.6,
#  10.6,
#  12.7,
#  14.1,
#  14.5,
#  15.7,
#  16.0,
#  16.4,
#  15.7,
#  14.6,
#  13.3,
#  12.5,
#  11.5,
#  10.6,
#  9.3]

# %%
import json
state_geo1 = json.load(open('TL_SCCO_SIG.json', encoding='utf-8'))

# %%
for idx, sigun_dict in enumerate(state_geo1['features']):
    if sigun_dict['properties']['SIG_KOR_NM'] =='안동시':
        print(idx)
# Out:
# 86

# %%
df.지점명.str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24 non-null     int64
#  1   일시          24 non-null     object
#  2   지점명         24 non-null     object
#  3   기온          24 non-null     float64
#  4   강수량         0 non-null      float64
#  5   풍속          24 non-null     float64
#  6   풍향          24 non-null     int64
#  7   습도          24 non-null     int64
#  8   실효습도        24 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 1.8+ KB

# %%
df['지점명'].dtype
# Out:
# dtype('O')

# %%
type(df['지점명'])
# Out:
# pandas.core.series.Series
