# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/산불발생일자19841201-20140619.csv')
df.head()
# Out:
#    Unnamed: 0          발생일시 발생일시(요일)   진화일시(년월일시분) 진화소요시간(분) 발생장소(관서)  \
# 0           0  201406191500        목  201406191800       300       북부
# 1           1  201406181805        수  201406182015       210       경남
# 2           2  201406151410        일  201406151720       310       강원
# 3           3  201406141720        토  201406141900       140       전북
# 4           4  201406101718        화  201406102000       242       북부
#
#   발생장소(시도) 발생장소(시군구) 발생장소(읍면동) 발생장소(리)  ...  평균기온 실효습도  상대습도  최소습도  최대풍속  \
# 0       강원        인제         남      남전  ...  23.6  0.0  57.0   0.0   5.6
# 1       경남        밀양       삼랑진      미전  ...  29.6  0.0  46.0   0.0   4.0
# 2       강원        인제        인제      가아  ...  29.3  0.0  57.0   0.0   6.7
# 3       전북        부안        보안      신복  ...  25.3  0.0  46.0   0.0   7.8
# 4       강원        원주        흥업      매지  ...  22.3  0.0  40.0   0.0   9.9
#
#    평균풍속  최대풍향  평균풍향  강우결과일수  최종강우량
# 0   1.9     S    SE       6    0.5
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0          발생일시 발생일시(요일)   진화일시(년월일시분) 진화소요시간(분) 발생장소(관서)  \
# 10195       10195  198412271900        목  198412272130       230       경북
# 10196       10196  198412091300        일  198412091320        20       서울
# 10197       10197  198412031150        월  198412031215        25       부산
# 10198       10198  198412021445        일  198412022145       700       경북
# 10199       10199  198412011505        토  198412011640       135       전남
#
#       발생장소(시도) 발생장소(시군구) 발생장소(읍면동) 발생장소(리)  ...  평균기온 실효습도  상대습도  최소습도  최대풍속  \
# 10195       경북        영천        임고      수성  ...  -3.5  0.0  47.0   0.0   0.0
# 10196       서울        은평        불광          ...  13.3  0.0  34.0   0.0   0.0
# 10197       부산        동래        명륜          ...  13.4  0.0  43.0   0.0   0.0
# 10198       경북        청도        각남      옥산  ...  10.6  0.0  19.0   0.0   0.0
# 10199       전남        여수        상암          ...  11.8  0.0  35.0   0.0   0.0
#
#        평균풍속  최대풍향  평균풍향  강우결과일수  최종강우량
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '발생일시', '발생일시(요일)', '진화일시(년월일시분)', '진화소요시간(분)',
#        '발생장소(관서)', '발생장소(시도)', '발생장소(시군구)', '발생장소(읍면동)', '발생장소(리)', '발생장소(지번)',
#        '소유구분', '발생세부원인', '피해면적', '피해액', '산불위험지수(평균)', '산불위험지수(최대)', '평균기온',
#        '실효습도', '상대습도', '최소습도', '최대풍속', '평균풍속', '최대풍향', '평균풍향', '강우결과일수',
#        '최종강우량'],
#       dtype='object')

# %%
df['발생세부원인'].value_counts()
# Out:
# 입산자실화추정       2400
# 입산자실화         1624
# 쓰레기소각          639
# 논밭두렁소각         538
# 성묘객실화          491
#               ...
# 움막화재확산           1
# 등산객담뱃불실화추정       1
# 수산폐기물소각추정        1
# 연탄재투기에의한실화       1
# 군부대사격            1
# Name: 발생세부원인, Length: 590, dtype: int64

# %%
df['발생세부원인'].values
# Out:
# array(['쓰레기소각', '담뱃불실화 추정', '도로공사(용접불티)비화', ..., '입산자실화', '입산자실화',
#        '입산자실화'], dtype=object)

# %%
df['최대풍향'].value_counts()
# Out:
#        8878
# WNW     135
# WSW     133
# W       120
# SW      113
# NW      106
# SSW      93
# NNW      88
# N        82
# S        77
# E        58
# ENE      57
# SSE      56
# ESE      53
# NNE      50
# SE       48
# NE       42
# 정온        8
# 7         1
# NS        1
# NN        1
# Name: 최대풍향, dtype: int64

# %%
df['실효습도'].describe()
# Out:
# count    10200.000000
# mean         3.797980
# std         12.695908
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         97.000000
# Name: 실효습도, dtype: float64

# %%
df['발생장소(시도)'].values
# Out:
# array(['강원', '경남', '강원', ..., '부산', '경북', '전남'], dtype=object)

# %%
location = pd.DataFrame(df.groupby('발생장소(시도)'))[0].values.tolist()

# %%
location
# Out:
# ['강원',
#  '경기',
#  '경남',
#  '경북',
#  '광주',
#  '대구',
#  '대전',
#  '부산',
#  '서부',
#  '서울',
#  '세종',
#  '울산',
#  '인천',
#  '전남',
#  '전북',
#  '전주',
#  '제주',
#  '출북',
#  '충남',
#  '충북']

# %%
강원 = df[df['발생장소(시도)'] ==  '강원']
경기 = df[df['발생장소(시도)'] ==  '경기']
경남 = df[df['발생장소(시도)'] ==  '경남']
경북 = df[df['발생장소(시도)'] ==  '경북']
광주 = df[df['발생장소(시도)'] ==  '광주']
대구 = df[df['발생장소(시도)'] ==  '대구']
대전 = df[df['발생장소(시도)'] ==  '대전']
부산 = df[df['발생장소(시도)'] ==  '부산']
서부 = df[df['발생장소(시도)'] ==  '서부']
서울 = df[df['발생장소(시도)'] ==  '서울']
세종 = df[df['발생장소(시도)'] ==  '세종']
울산 = df[df['발생장소(시도)'] ==  '울산']
인천 = df[df['발생장소(시도)'] ==  '인천']
전남 = df[df['발생장소(시도)'] ==  '전남']
전북 = df[df['발생장소(시도)'] ==  '전북']
전주 = df[df['발생장소(시도)'] ==  '전주']
제주 = df[df['발생장소(시도)'] ==  '제주']
출북 = df[df['발생장소(시도)'] ==  '출북']
충남 = df[df['발생장소(시도)'] ==  '충남']
충북 = df[df['발생장소(시도)'] ==  '충북']

# %%
강원['발생장소(시군구)'].value_counts()
# Out:
# 춘천    196
# 강릉    154
# 홍천    152
# 원주    111
# 인제     95
# 삼척     88
# 영월     87
# 횡성     85
# 평창     66
# 고성     65
# 정선     61
# 양양     58
# 화천     47
# 양구     45
# 태백     40
# 동해     36
# 철원     32
# 속초     16
# Name: 발생장소(시군구), dtype: int64

# %%
강원['최대풍향'].value_counts()
# Out:
#        1229
# WSW      25
# SW       24
# SSW      20
# NW       15
# W        14
# N        14
# WNW      14
# S        13
# ESE      10
# NE        9
# SSE       9
# ENE       9
# E         8
# NNW       8
# SE        7
# NNE       4
# NS        1
# 정온        1
# Name: 최대풍향, dtype: int64

# %%
강원['발생일시']=강원['발생일시'].astype(str)
# Out:
# C:\Users\wease\AppData\Local\Temp\ipykernel_9360\2019339622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   강원['발생일시']=강원['발생일시'].astype(str)

# %%
강원['발생일시'] = pd.to_datetime(강원['발생일시'])
# Out:
# C:\Users\wease\AppData\Local\Temp\ipykernel_9360\3096232626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   강원['발생일시'] = pd.to_datetime(강원['발생일시'])

# %%
강원
# Out:
#        Unnamed: 0                발생일시 발생일시(요일)   진화일시(년월일시분) 진화소요시간(분)  \
# 0               0 2014-06-19 15:00:00        목  201406191800       300
# 2               2 2014-06-15 14:10:00        일  201406151720       310
# 4               4 2014-06-10 17:18:00        화  201406102000       242
# 8               8 2014-06-01 21:45:00        일  201406020150       405
# 11             11 2014-05-31 17:02:00        토  201405311904       202
# ...           ...                 ...      ...           ...       ...
# 10189       10189 1985-03-02 17:20:00        토  198503021730        10
# 10190       10190 1985-03-02 17:10:00        토  198503021712         2
# 10191       10191 1985-02-25 15:50:00        월  198502251600        10
# 10192       10192 1985-02-25 14:10:00        월  198502251430        20
# 10193       10193 1985-02-23 22:30:00        토  198502232300        30
#
#       발생장소(관서) 발생장소(시도) 발생장소(시군구) 발생장소(읍면동) 발생장소(리)  ...  평균기온 실효습도  상대습도  \
# ...

# %%
강원['Month'] = 강원['발생일시'].dt.month
강원['Month'].value_counts()
# Out:
# C:\Users\wease\AppData\Local\Temp\ipykernel_9360\53200874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   강원['Month'] = 강원['발생일시'].dt.month
# 4     570
# 3     243
# 5     159
# 2     133
# 11     76
# 12     74
# 1      66
# 10     54
# 6      53
# 8       4
# 9       1
# 7       1
# Name: Month, dtype: int64

# %%
spring = 강원[(강원['Month'] == 3)| (강원['Month'] == 4) |(강원['Month'] == 5)]

# %%
spring
# Out:
#        Unnamed: 0                발생일시 발생일시(요일)   진화일시(년월일시분) 진화소요시간(분)  \
# 11             11 2014-05-31 17:02:00        토  201405311904       202
# 16             16 2014-05-30 10:00:00        금  201405301400       400
# 20             20 2014-05-28 15:40:00        수  201405281905       325
# 24             24 2014-05-26 12:10:00        월  201405261410       200
# 41             41 2014-05-14 18:24:00        수  201405141940       116
# ...           ...                 ...      ...           ...       ...
# 10184       10184 1985-03-22 14:12:00        금  198503221500        48
# 10185       10185 1985-03-22 14:00:00        금  198503221430        30
# 10187       10187 1985-03-20 13:30:00        수  198503201340        10
# 10189       10189 1985-03-02 17:20:00        토  198503021730        10
# 10190       10190 1985-03-02 17:10:00        토  198503021712         2
#
#       발생장소(관서) 발생장소(시도) 발생장소(시군구) 발생장소(읍면동) 발생장소(리)  ... 실효습도  상대습도 최소습도  \
# ...

# %%
강원['발생일시(요일)'].value_counts()
# Out:
# 일    263
# 월    210
# 수    207
# 금    200
# 목    198
# 화    185
# 토    171
# Name: 발생일시(요일), dtype: int64

# %%
강원['hour'] = 강원['발생일시'].dt.hour
# Out:
# C:\Users\wease\AppData\Local\Temp\ipykernel_9360\1755350622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   강원['hour'] = 강원['발생일시'].dt.hour

# %%
강원['hour'].value_counts()
# Out:
# 14    240
# 13    221
# 15    180
# 12    167
# 16    127
# 11    126
# 17     71
# 10     60
# 19     38
# 18     32
# 21     20
# 9      17
# 20     17
# 3      16
# 4      15
# 2      14
# 23     12
# 22     12
# 8      11
# 5      11
# 1       8
# 7       7
# 6       6
# 0       6
# Name: hour, dtype: int64
